# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break
# Out:
# Reached 5 sec

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# Experimenting with task.py and physics_sim.py
# Q: Can the vehicle hover under fixed equal thrust?

class Exp_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = 404
        return [new_thrust for x in range(4)]

runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Exp_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.

for k in range(200):  # 200 / 50 * 3 = 12 sec (dt = 0.02 sec, action_repeat = 3)
    rotor_speeds = agent.act()
    _, _, done = task.step(rotor_speeds)
    to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
    for ii in range(len(labels)):
        results[labels[ii]].append(to_write[ii])
        
plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 200 #1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =    2, score =  -2.495 (best =  -2.495), noise_scale = 0.025
# /home/honeywell/anaconda2/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Episode =   92, score =  -4.259 (best =   5.502), noise_scale = 3.2625Reached 5 sec
# Episode =   97, score =  -2.442 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  100, score =  -2.089 (best =   5.502), noise_scale = 3.2
# /home/honeywell/Projects/Udacity/DeepLearning/Part6_ReinforcedLearning/Project-Quadcopter/2018-07-02/physics_sim.py:91: RuntimeWarning: overflow encountered in multiply
#   drag_moment =  self.C_d * 0.5 * self.rho * self.angular_v * np.absolute(self.angular_v) * self.areas * self.dims * self.dims
# /home/honeywell/Projects/Udacity/DeepLearning/Part6_ReinforcedLearning/Project-Quadcopter/2018-07-02/physics_sim.py:134: RuntimeWarning: invalid value encountered in remainder
#   angles = (angles + 2 * np.pi) % (2 * np.pi)
# /home/honeywell/Projects/Udacity/DeepLearning/Part6_ReinforcedLearning/Project-Quadcopter/2018-07-02/physics_sim.py:117: RuntimeWarning: overflow encountered in double_scalars
#   C_T = max(.12 - .07*max(0, J)-.1*max(0, J)**2, 0)
# Episode =  103, score =  -2.933 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  105, score =  -3.444 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  109, score =  -1.958 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  116, score =  -2.969 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  120, score =  -4.597 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  124, score =  -1.938 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  128, score =  -2.596 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  131, score =  -2.791 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  195, score =  -2.384 (best =   5.502), noise_scale = 3.2Reached 5 sec
# Episode =  200, score =  -3.271 (best =   5.502), noise_scale = 3.2

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
import tensorflow as tf
import numpy as np
import agents.agent as agent
from task import Task
import matplotlib.pyplot as plt
import random

# ===========================
#   Agent Training
# ===========================

def train(sess, ddpg, max_episodes):

    summary_dir = './results'
    #max_episodes = 2
    max_episode_len = 200

    # Set up summary Ops
    summary_ops, summary_vars = build_summaries()

    sess.run(tf.global_variables_initializer())
    #writer = tf.summary.FileWriter(summary_dir, sess.graph)

    # Initialize replay memory
    buffer_size = ddpg.buffer_size
    batch_size = ddpg.batch_size
    replay_buffer = agent.ReplayBuffer(buffer_size, batch_size)

    reward_all = np.array([], dtype=float)

    for i in range(max_episodes):

        # Reset
        state = ddpg.reset_episode()

        ep_reward = 0
        ep_ave_max_q = 0

        for j in range(max_episode_len):

            # Get action from state
            action = ddpg.act(state)

            # Ideal Solution
            #action = np.ones(4)*405

            # Take a step (Get state, action, reward, next_state, done)
            next_state, reward, done = ddpg.task.step(action)

            # Keep adding experience until buffer full
            replay_buffer.add(state, action, reward, next_state, done)

            # If buffer full:
            #   - Get batches of experience (states, actions, reward, next_state, done)
            #   - Learn

            if replay_buffer.__len__() >  ddpg.batch_size:

                experiences = replay_buffer.sample(batch_size)
                ddpg.learn(experiences)
                ep_ave_max_q += ddpg.Qmax   # IS THIS RIGHT Q TO LOOK AT?

            if j == 0:
                action_save = action
                state_save = state
            else:
                action_save = np.vstack([action_save, action])
                state_save = np.vstack([state_save, state])

            state = next_state
            ep_reward += reward

            if done:

                summary_str = sess.run(summary_ops, feed_dict={
                    summary_vars[0]: ep_reward,
                    summary_vars[1]: ep_ave_max_q / (float(j+1))
                })

                #writer.add_summary(summary_str, i)
                #writer.flush()

                #print(state)
                #print(action)

                print('| Reward: {:d} | Episode: {:d} | Episode Length: {:d} | Rotorspeeds: {:d} {:d} {:d} {:d}'.format(int(ep_reward), \
                        i, j, int(action[0]), int(action[1]), int(action[2]), int(action[3]) ))


                if False:
                    nm = action_save.shape
                    n = nm[0]
                    t = np.arange(0,n)*0.02

                    plt.figure(1)

                    plt.subplot(211)
                    plt.plot(t,action_save)
                    plt.grid('on')
                    plt.ylabel('rpm')

                    plt.subplot(212)
                    plt.plot(t,state_save[:,2])
                    plt.grid('on')
                    plt.ylabel('h [m]')
                    plt.xlabel('t [sec]')

                    plt.pause(0.2)

                    if i == max_episodes-1:
                        plt.figure(1)
                        plt.savefig('./results/fig1.jpg')

                    if i < max_episodes-1:
                        plt.clf()

                    plt.figure(2)
                    plt.plot(i, ep_reward, 'bo')
                    plt.grid('on')
                    plt.xlabel('Iteration')
                    plt.ylabel('Episode Reward')

                    if i == max_episodes-1:

                        plt.figure(2)
                        plt.savefig('./results/fig2.jpg')

                reward_all = np.concatenate([reward_all, [ep_reward]])

                break

    return reward_all


# ===========================
#   Tensorflow Summary Ops
# ===========================

def build_summaries():
    episode_reward = tf.Variable(0.)
    tf.summary.scalar("Reward", episode_reward)
    episode_ave_max_q = tf.Variable(0.)
    tf.summary.scalar("Qmax_Value", episode_ave_max_q)

    summary_vars = [episode_reward, episode_ave_max_q]
    summary_ops = tf.summary.merge_all()

    return summary_ops, summary_vars


def main(max_episodes):


    with tf.Session() as sess:

        # Task: take-off and hover
        init_pose = [0.0, 0.0, 10.0, 0.0, 0.0, 0.0]
        init_velocities = [0.0, 0.0, 0.0]
        init_angle_velocities = [0.0, 0.0, 0.0]
        run_time = 20
        target_pos = [0.0, 0.0, 10.0]

        np.random.seed(1234)
        random.seed(2345)

        ddpg = agent.DDPG(Task(init_pose, init_velocities, init_angle_velocities, run_time, target_pos))

        reward_all = train(sess, ddpg, max_episodes)

        print('done')

        return reward_all


if __name__ == '__main__':
    
    max_episodes = 100
    
    reward_all = main(max_episodes)
# Out:
# | Reward: -187 | Episode: 0 | Episode Length: 90 | Rotorspeeds: 3 11 898 892
# | Reward: 468 | Episode: 1 | Episode Length: 178 | Rotorspeeds: 900 900 900 797
# | Reward: 303 | Episode: 2 | Episode Length: 138 | Rotorspeeds: 899 900 900 900
# | Reward: 4 | Episode: 3 | Episode Length: 158 | Rotorspeeds: 5 900 900 900
# | Reward: -188 | Episode: 4 | Episode Length: 83 | Rotorspeeds: 900 900 900 3
# | Reward: -166 | Episode: 5 | Episode Length: 80 | Rotorspeeds: 900 900 900 894
# | Reward: -202 | Episode: 6 | Episode Length: 74 | Rotorspeeds: 900 900 890 899
# | Reward: -160 | Episode: 7 | Episode Length: 77 | Rotorspeeds: 77 899 85 899
# | Reward: -214 | Episode: 8 | Episode Length: 82 | Rotorspeeds: 899 900 1 899
# | Reward: -252 | Episode: 9 | Episode Length: 80 | Rotorspeeds: 832 900 1 1
# | Reward: -210 | Episode: 10 | Episode Length: 77 | Rotorspeeds: 872 900 1 1
# | Reward: -200 | Episode: 11 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 12 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 13 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 14 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 15 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 16 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 17 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 18 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 19 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 20 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 21 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 22 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 23 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 24 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 25 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 26 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 27 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 28 | Episode Length: 76 | Rotorspeeds: 1 900 1 1
# | Reward: -200 | Episode: 29 | Episode Length: 76 | Rotorspeeds: 1 899 1 1
# | Reward: -192 | Episode: 30 | Episode Length: 75 | Rotorspeeds: 1 1 1 1
# | Reward: -191 | Episode: 31 | Episode Length: 68 | Rotorspeeds: 1 1 12 1
# | Reward: -227 | Episode: 32 | Episode Length: 79 | Rotorspeeds: 1 1 1 1
# | Reward: -172 | Episode: 33 | Episode Length: 67 | Rotorspeeds: 169 1 872 1
# | Reward: -207 | Episode: 34 | Episode Length: 73 | Rotorspeeds: 899 1 1 1
# | Reward: -198 | Episode: 35 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 36 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 37 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 38 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 39 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 40 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 41 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 42 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 43 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 44 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 45 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 46 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 47 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 48 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 49 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 50 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 51 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 52 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 53 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 54 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 55 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 56 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 57 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 58 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 59 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 60 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 61 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 62 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 63 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 64 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 65 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 66 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 67 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 68 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 69 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 70 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 71 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 72 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 73 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 74 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 75 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 76 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 77 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 78 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 79 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 80 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 81 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 82 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 83 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 84 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 85 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 86 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 87 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 88 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 89 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 90 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 91 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 92 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 93 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 94 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 95 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 96 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 97 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 98 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# | Reward: -198 | Episode: 99 | Episode Length: 75 | Rotorspeeds: 900 1 1 1
# done

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.

plt.figure(3)
plt.plot(reward_all)
plt.ylim(-300, 100)
plt.grid('on')
plt.ylabel('Reward')
plt.xlabel('Episode Number')
plt.pause(0.02)

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**: I set the task as takeoff - starting position = [0, 0, 0] m, desired position = [0, 0, 10] m
#
# We want minimum change in direction of x and y and making z close to the target z, so we punish for moving in directions x and y and reward motion in the z direction w.r.t. the desired z. We also, punish the angular motion.
#
# See function task.py > get_reward() for the expression for reward.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
# - Tried SARSA, Deep Q-learning and Actor-Critic. Actor-Critic worked best as it provides the right framework for implementing continuous values of action and state.
# - The following values are used for hyper-parameters:
#         exploration_mu = 0 # OU noise
#         exploration_theta = 0.1  # OU noise
#         exploration_sigma = 1  # OU noise
#         batch_size = 64 # size of batch
#         gamma = 0.99  # discount factor
#         tau = 0.01  # for soft update of target parameters
#         lr = 0.001 # learing rate for adam optimizer
#
# - Neural Network:
#     Actor:
#         Dense(units=400, activation='relu')
#         Dense(units=300, activation='relu')
#     Critic:
#         Action Pathway:
#             Dense(units=400, activation='relu')
#             Dense(units=300, activation='relu')
#         State Pathway:
#             Dense(units=300, activation='relu')

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
# The solution is either conveging to local minima or oscillating between the min and max values. I tried several combinations of the hyper-parameters but didn't see any noticeable change in the convergence.
#
# Please provide ballpark values for the hyper-parameters and the neural network architecture.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
